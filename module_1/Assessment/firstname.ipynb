# %% [markdown]
# ## Loops & Dictionaries (10 minutes)
# Create a nested dictionary of recipes, with keys at the top level and dictionaries as their associated values.
#
# 1. Create an empty dictionary named `recipes`.
# 1. Add three dishes as the **keys** of your dictionary (e.g. 'meat pie')
# 1. For each key, the **value** should be another dictionary consisting of `ingredient: amount` pairs. (eg `'sugar': 'two cups'`) Each dish should have three ingredients.
# 1. Write a function to process the recipe dictionary. This function should loop through the recipes and return a single list of all ingredients for all recipes.

# %%
recipes = {}

# %%
keys = ['meat pie', 'meat ball', 'kabob']

# %%
values = [{'sugar': '3 cups', 'chicken' : '6lbs', 'cheese' : '4lbs'}, 
          {'sugar': 'two cups', 'chicken' : '5lbs', 'cheese' : '1lb'},
          {'sugar': 'one cup', 'chicken' : '3lbs', 'cheese' : '2lbs'}]

# %%
all_recipes = ['meat pie':{'sugar': '3 cups', 'chicken' : '6lbs', 'cheese' : '4lbs'}, 'meat ball': {'sugar': 'two cups', 'chicken' : '5lbs', 'cheese' : '1lb'}, 'kabob': {'sugar': 'one cup', 'chicken' : '3lbs', 'cheese' : '2lbs'}]

# %%
recipes_dictionary = dict(zip(keys, values))
recipes_dictionary
# Out:
# {'meat pie': {'sugar': '3 cups', 'chicken': '6lbs', 'cheese': '4lbs'},
#  'meat ball': {'sugar': 'two cups', 'chicken': '5lbs', 'cheese': '1lb'},
#  'kabob': {'sugar': 'one cup', 'chicken': '3lbs', 'cheese': '2lbs'}}

# %%
def get_recipes(info_dict):
    name = []
    for dish in info_dict:
        name.append({},{}).format(info_dict[0],info_dict[1])
    
    return name

# %%
get_recipes(recipes_dictionary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-7baecf3c7618> in <module>
# ----> 1 get_recipes(recipes_dictionary)
#
# <ipython-input-81-2c5235429029> in get_recipes(info_dict)
#       2     name = []
#       3     for dish in info_dict:
# ----> 4         name.append({},{}).format(info_dict[0],info_dict[1])
#       5
#       6     return name
#
# TypeError: append() takes exactly one argument (2 given)

# %% [markdown]
# ## Coding Readibility (5 Minutes)
# Rewrite the code below in using best practices:
# ```python
# def blabla():
# for i in range ( 10 ):for j in range( 10 ):for k in range(10): print( i,j,k ) return everything
# ```

# %%
def blabla():
    for i in range(10):
        for j in range(10):
            for k in range(10):
                print(i)
                print(j)
                print(k)
    return i, j, k

# %% [markdown]
# ## Data cleaning (15 Minutes)
# read data from http://rattle.togaware.com/weatherAUS.csv
# 1. Add a `day`, `month`, and `year` column (three new columns)
# 1. Print out the name of the columns where there are missing values
# 1. Drop all columns except `day`, `month`, `year`, `Rainfall`, and `Sunshine`
# 1. Fill all missing `Rainfall` values as follows:
#   1. If `Sunshine` is over 7.0, set `Rainfall` = 0
#   2. Else (including if `Sunshine is NaN`) set `Rainfall` to the mean `Rainfall` value.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


df = pd.read_csv('http://rattle.togaware.com/weatherAUS.csv')
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
# 5         WNW           56.0          W  ...        23.0       1009.2
# 6           W           50.0         SW  ...        19.0       1009.6
# 7           W           35.0        SSE  ...        19.0       1013.4
# 8         NNW           80.0         SE  ...         9.0       1008.9
# 9           W           28.0          S  ...        27.0       1007.0
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
# 3       1012.8       NaN       NaN     18.1     26.5         No      1.0
# 4       1006.0       7.0       8.0     17.8     29.7         No      0.2
# 5       1005.4       NaN       NaN     20.6     28.9         No      0.0
# 6       1008.2       1.0       NaN     18.1     24.6         No      0.0
# 7       1010.1       NaN       NaN     16.3     25.5         No      0.0
# 8       1003.6       NaN       NaN     18.3     30.2         No      1.4
# 9       1005.7       NaN       NaN     20.1     28.2        Yes      0.0
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# 5            No
# 6            No
# 7            No
# 8           Yes
# 9            No
#
# [10 rows x 24 columns]

# %%
# There is no missing value in Dataset
for col in df.columns:
    if df[col].dtype == object:
         print(col, df[col][df[col] == '?'].count())
print(df.shape)
# Out:
# Date 0
# Location 0
# WindGustDir 0
# WindDir9am 0
# WindDir3pm 0
# RainToday 0
# RainTomorrow 0
# (157344, 24)

# %%
# examine the bool & object with describe, 
df.describe(include=['object', 'bool'])
# Out:
#           Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count   157344    157344      145694     145556     151978    153737
# unique       1        49          16         16         16         2
# top             Canberra           W          N         SE        No
# freq    157344      3680       10658      12453      11684    120242
#
#        RainTomorrow   Month    Year
# count        153738  157344  157344
# unique            2       1       1
# top              No
# freq         120232  157344  157344

# %%
#df = df.drop(['', ''], axis = 1, inplace = True)

# %%
#Drop all columns except `day`, `month`, `year`, `Rainfall`, and `Sunshine`
#Create new dataframe with only those index columns
df1 = df.iloc[:,[4, 6]]
df1
# Out:
#         Rainfall  Sunshine
# 0            0.6       NaN
# 1            0.0       NaN
# 2            0.0       NaN
# 3            0.0       NaN
# 4            1.0       NaN
# 5            0.2       NaN
# 6            0.0       NaN
# 7            0.0       NaN
# 8            0.0       NaN
# 9            1.4       NaN
# 10           0.0       NaN
# 11           2.2       NaN
# 12          15.6       NaN
# 13           3.6       NaN
# 14           0.0       NaN
# 15           NaN       NaN
# 16           0.0       NaN
# 17          16.8       NaN
# 18          10.6       NaN
# 19           0.0       NaN
# 20           0.0       NaN
# 21           0.0       NaN
# 22           0.0       NaN
# 23           0.0       NaN
# 24           0.0       NaN
# 25           0.0       NaN
# 26           0.0       NaN
# 27           0.0       NaN
# 28           0.0       NaN
# 29           1.2       NaN
# ...          ...       ...
# 157314       0.0       NaN
# 157315       0.0       NaN
# 157316       0.0       NaN
# 157317       0.0       NaN
# 157318       0.0       NaN
# 157319       0.0       NaN
# 157320       0.0       NaN
# 157321       0.0       NaN
# 157322       0.0       NaN
# 157323       0.0       NaN
# 157324       0.0       NaN
# 157325       0.0       NaN
# 157326       0.0       NaN
# 157327       0.0       NaN
# 157328       0.0       NaN
# 157329       0.0       NaN
# 157330       0.0       NaN
# 157331       0.0       NaN
# 157332       0.0       NaN
# 157333       0.0       NaN
# 157334       0.0       NaN
# 157335       0.0       NaN
# 157336       0.0       NaN
# 157337       0.0       NaN
# 157338       0.0       NaN
# 157339       0.0       NaN
# 157340       0.0       NaN
# 157341       0.0       NaN
# 157342       0.0       NaN
# 157343       0.0       NaN
#
# [157344 rows x 2 columns]

# %%
#Add a 'day', 'month', and 'year' column (three new columns)
df['Day'] = df.apply(lambda _: '', axis=1)
df['Month'] = df.apply(lambda _: '', axis=1)
df['Year'] = df.apply(lambda _: '', axis=1)

df
# Out:
#        Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0             Albury     13.4     22.9       0.6          NaN       NaN
# 1             Albury      7.4     25.1       0.0          NaN       NaN
# 2             Albury     12.9     25.7       0.0          NaN       NaN
# 3             Albury      9.2     28.0       0.0          NaN       NaN
# 4             Albury     17.5     32.3       1.0          NaN       NaN
# 5             Albury     14.6     29.7       0.2          NaN       NaN
# 6             Albury     14.3     25.0       0.0          NaN       NaN
# 7             Albury      7.7     26.7       0.0          NaN       NaN
# 8             Albury      9.7     31.9       0.0          NaN       NaN
# 9             Albury     13.1     30.1       1.4          NaN       NaN
# 10            Albury     13.4     30.4       0.0          NaN       NaN
# 11            Albury     15.9     21.7       2.2          NaN       NaN
# 12            Albury     15.9     18.6      15.6          NaN       NaN
# 13            Albury     12.6     21.0       3.6          NaN       NaN
# 14            Albury      8.4     24.6       0.0          NaN       NaN
# 15            Albury      9.8     27.7       NaN          NaN       NaN
# 16            Albury     14.1     20.9       0.0          NaN       NaN
# 17            Albury     13.5     22.9      16.8          NaN       NaN
# 18            Albury     11.2     22.5      10.6          NaN       NaN
# 19            Albury      9.8     25.6       0.0          NaN       NaN
# 20            Albury     11.5     29.3       0.0          NaN       NaN
# 21            Albury     17.1     33.0       0.0          NaN       NaN
# 22            Albury     20.5     31.8       0.0          NaN       NaN
# 23            Albury     15.3     30.9       0.0          NaN       NaN
# 24            Albury     12.6     32.4       0.0          NaN       NaN
# 25            Albury     16.2     33.9       0.0          NaN       NaN
# 26            Albury     16.9     33.0       0.0          NaN       NaN
# 27            Albury     20.1     32.7       0.0          NaN       NaN
# 28            Albury     19.7     27.2       0.0          NaN       NaN
# 29            Albury     12.5     24.2       1.2          NaN       NaN
# ...     ...      ...      ...      ...       ...          ...       ...
# 157314         Uluru     20.4     42.0       0.0          NaN       NaN
# 157315         Uluru     22.7     41.7       0.0          NaN       NaN
# 157316         Uluru     24.3     41.3       0.0          NaN       NaN
# 157317         Uluru     23.8     40.0       0.0          NaN       NaN
# 157318         Uluru     23.1     40.4       0.0          NaN       NaN
# 157319         Uluru     23.1     37.1       0.0          NaN       NaN
# 157320         Uluru     22.0     38.4       0.0          NaN       NaN
# 157321         Uluru     22.2     41.3       0.0          NaN       NaN
# 157322         Uluru     22.8     41.9       0.0          NaN       NaN
# 157323         Uluru     22.0     44.3       0.0          NaN       NaN
# 157324         Uluru     23.7     44.8       0.0          NaN       NaN
# 157325         Uluru     26.8     41.5       0.0          NaN       NaN
# 157326         Uluru     24.6     40.1       0.0          NaN       NaN
# 157327         Uluru     25.6     37.0       0.0          NaN       NaN
# 157328         Uluru     25.9     34.7       0.0          NaN       NaN
# 157329         Uluru     18.9     34.6       0.0          NaN       NaN
# 157330         Uluru     22.7     37.7       0.0          NaN       NaN
# 157331         Uluru     21.8     38.7       0.0          NaN       NaN
# 157332         Uluru     22.4     39.8       0.0          NaN       NaN
# 157333         Uluru     24.0     39.3       0.0          NaN       NaN
# 157334         Uluru     21.8     40.2       0.0          NaN       NaN
# 157335         Uluru     19.4     41.3       0.0          NaN       NaN
# 157336         Uluru     21.3     42.1       0.0          NaN       NaN
# 157337         Uluru     24.6     39.2       0.0          NaN       NaN
# 157338         Uluru     24.3     33.2       0.0          NaN       NaN
# 157339         Uluru     18.7     31.3       0.0          NaN       NaN
# 157340         Uluru     14.6     32.0       0.0          NaN       NaN
# 157341         Uluru     13.7     34.0       0.0          NaN       NaN
# 157342         Uluru     14.3     36.0       0.0          NaN       NaN
# 157343         Uluru     14.1     28.0       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am  ... Cloud9am  Cloud3pm  Temp9am  \
# 0                W           44.0          W  ...      8.0       NaN     16.9
# 1              WNW           44.0        NNW  ...      NaN       NaN     17.2
# 2              WSW           46.0          W  ...      NaN       2.0     21.0
# 3               NE           24.0         SE  ...      NaN       NaN     18.1
# 4                W           41.0        ENE  ...      7.0       8.0     17.8
# 5              WNW           56.0          W  ...      NaN       NaN     20.6
# 6                W           50.0         SW  ...      1.0       NaN     18.1
# 7                W           35.0        SSE  ...      NaN       NaN     16.3
# 8              NNW           80.0         SE  ...      NaN       NaN     18.3
# 9                W           28.0          S  ...      NaN       NaN     20.1
# 10               N           30.0        SSE  ...      NaN       NaN     20.4
# 11             NNE           31.0         NE  ...      8.0       8.0     15.9
# 12               W           61.0        NNW  ...      8.0       8.0     17.4
# 13              SW           44.0          W  ...      NaN       7.0     15.8
# 14             NaN            NaN          S  ...      NaN       NaN     15.9
# 15             WNW           50.0        NaN  ...      0.0       NaN     17.3
# 16             ENE           22.0        SSW  ...      8.0       1.0     17.2
# 17               W           63.0          N  ...      8.0       1.0     18.0
# 18             SSE           43.0        WSW  ...      NaN       2.0     15.5
# 19             SSE           26.0         SE  ...      NaN       NaN     15.8
# 20               S           24.0         SE  ...      NaN       NaN     19.1
# 21              NE           43.0         NE  ...      NaN       1.0     24.5
# 22             WNW           41.0          W  ...      NaN       NaN     23.8
# 23               N           33.0        ESE  ...      5.0       NaN     20.9
# 24               W           43.0          E  ...      NaN       NaN     21.5
# 25             WSW           35.0         SE  ...      NaN       1.0     23.2
# 26             WSW           57.0        NaN  ...      NaN       1.0     26.6
# 27             WNW           48.0          N  ...      NaN       NaN     24.6
# 28             WNW           46.0         NW  ...      NaN       NaN     21.6
# 29             WNW           50.0        WSW  ...      8.0       8.0     12.5
# ...            ...            ...        ...  ...      ...       ...      ...
# 157314         NNW           39.0         NE  ...      NaN       NaN     31.9
# 157315           N           39.0         NE  ...      NaN       3.0     32.5
# 157316           E           43.0         NE  ...      NaN       NaN     33.1
# 157317         ESE           52.0        ESE  ...      NaN       NaN     32.0
# 157318           E           43.0        ENE  ...      NaN       NaN     32.0
# 157319           E           44.0         SE  ...      NaN       NaN     26.1
# 157320           E           41.0          E  ...      NaN       NaN     25.2
# 157321         ESE           31.0          E  ...      NaN       NaN     28.9
# 157322           E           54.0        ENE  ...      NaN       NaN     30.7
# 157323          NE           35.0        ENE  ...      NaN       NaN     34.2
# 157324          SW           43.0          N  ...      4.0       NaN     34.2
# 157325           E           43.0        ESE  ...      2.0       NaN     32.4
# 157326           E           43.0          E  ...      NaN       NaN     29.9
# 157327         SSE           57.0          E  ...      5.0       4.0     30.7
# 157328           E           41.0          E  ...      NaN       7.0     29.4
# 157329         ENE           35.0          E  ...      7.0       8.0     28.2
# 157330           S           43.0        ENE  ...      NaN       7.0     28.9
# 157331         ESE           43.0          E  ...      NaN       NaN     29.2
# 157332           E           50.0        ENE  ...      NaN       5.0     29.6
# 157333           E           43.0          E  ...      NaN       1.0     30.7
# 157334         ESE           44.0        ENE  ...      NaN       NaN     30.6
# 157335          NE           41.0         NE  ...      NaN       NaN     30.5
# 157336         SSE           57.0        ENE  ...      NaN       NaN     31.4
# 157337           S           50.0        ESE  ...      NaN       NaN     28.4
# 157338         ESE           48.0         SE  ...      1.0       1.0     26.4
# 157339         SSE           44.0        ESE  ...      NaN       NaN     21.9
# 157340           E           35.0          E  ...      NaN       NaN     22.1
# 157341         ENE           28.0          E  ...      NaN       NaN     22.8
# 157342         SSE           46.0          S  ...      NaN       NaN     24.8
# 157343         SSE           48.0         SE  ...      NaN       NaN     17.5
#
#         Temp3pm  RainToday  RISK_MM  RainTomorrow  Month  Year  Day
# 0          21.8         No      0.0            No
# 1          24.3         No      0.0            No
# 2          23.2         No      0.0            No
# 3          26.5         No      1.0            No
# 4          29.7         No      0.2            No
# 5          28.9         No      0.0            No
# 6          24.6         No      0.0            No
# 7          25.5         No      0.0            No
# 8          30.2         No      1.4           Yes
# 9          28.2        Yes      0.0            No
# 10         28.8         No      2.2           Yes
# 11         17.0        Yes     15.6           Yes
# 12         15.8        Yes      3.6           Yes
# 13         19.8        Yes      0.0            No
# 14         23.5         No      NaN           NaN
# 15         26.2        NaN      0.0            No
# 16         18.1         No     16.8           Yes
# 17         21.5        Yes     10.6           Yes
# 18         21.0        Yes      0.0            No
# 19         23.2         No      0.0            No
# 20         27.3         No      0.0            No
# 21         31.6         No      0.0            No
# 22         30.8         No      0.0            No
# 23         29.0         No      0.0            No
# 24         31.2         No      0.0            No
# 25         33.0         No      0.0            No
# 26         31.2         No      0.0            No
# 27         32.1         No      0.0            No
# 28         26.1         No      1.2           Yes
# 29         18.2        Yes      0.8            No
# ...         ...        ...      ...           ...    ...   ...  ...
# 157314     40.2         No      0.0            No
# 157315     40.5         No      0.0            No
# 157316     39.7         No      0.0            No
# 157317     39.8         No      0.0            No
# 157318     39.9         No      0.0            No
# 157319     36.0         No      0.0            No
# 157320     36.5         No      0.0            No
# 157321     40.3         No      0.0            No
# 157322     41.2         No      0.0            No
# 157323     42.6         No      0.0            No
# 157324     43.6         No      0.0            No
# 157325     40.3         No      0.0            No
# 157326     38.1         No      0.0            No
# 157327     34.4         No      0.0            No
# 157328     33.4         No      0.0            No
# 157329     33.9         No      0.0            No
# 157330     35.7         No      0.0            No
# 157331     36.9         No      0.0            No
# 157332     38.5         No      0.0            No
# 157333     37.7         No      0.0            No
# 157334     38.2         No      0.0            No
# 157335     39.5         No      0.0            No
# 157336     39.7         No      0.0            No
# 157337     37.3         No      0.0            No
# 157338     31.3         No      0.0            No
# 157339     29.8         No      0.0            No
# 157340     30.5         No      0.0            No
# 157341     32.5         No      0.0            No
# 157342     34.3         No      0.0            No
# 157343     27.3         No      0.0            No
#
# [157344 rows x 27 columns]

# %% [markdown]
# ## Visualization (15 Minutes)
#
# As best you can, recreate this bar chart created in Google Sheets using Python.  You may use Matplotlib, Seaborn, or any other graphing library you came across.
# <img src="chart.jpg" alt="chart to recreate" width="500"/>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()

data = [['A', 54], ['B', 23], ['C', 99],['D', 37], ['E', 3] ] 
df = pd.DataFrame(data, columns = ['Category', 'Count'])
df
# Out:
#   Category  Count
# 0        A     54
# 1        B     23
# 2        C     99
# 3        D     37
# 4        E      3

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# Make fake dataset
x = list(df['Count'])
bars = list(df['Category'])
y_pos = np.arange(len(bars))
 
# Create horizontal bars
plt.barh(y_pos, x, color = 'red')
 
# Create names on the y-axis
plt.yticks(y_pos, bars)

plt.xlabel('Count')
plt.ylabel('Category')
# Add a title for the plot
plt.title('Count by Category')

print(x)
print(y)
# Show graphic
plt.show()
# Out:
# [54, 23, 99, 37, 3]
# ['A', 'B', 'C', 'D', 'E']

# %% [markdown]
# ![Friday%20feeling.gif](attachment:Friday%20feeling.gif)

# %% [markdown]
# ## Github (5 Minutes)
#
# Follow the instructions at https://github.com/enkeboll/fis-dc-ds-060319-gifs, and make sure to check your email to confirm your collaborator status!

# %% [markdown]
# # Assessment submission (2 Minutes)
# Please save this file as `firstname.ipynb` and upload it using [this form](https://docs.google.com/forms/d/e/1FAIpQLSdlnMgc5Nb5uFTmw7DiScapevg-VA8DQdiFeIAil5sZqYZbFA/viewform)
