# %% [markdown]
# # Introduction to APIs

# %% [markdown]
# # What is an API?

# %% [markdown]
# An API (Application Programming Interface) is a way for one system to interact with another via a well-defined interface. An interface is any endpoint that can be used to take actions and consume data on a given application. The HTML response of every web site is an interface, for instance.
#
# The web interface provides HTML, which is a combination of data (the dynamic values like venue names, addresses, and check-ins) and presentation (HTML tags, CSS classes, JavaScript effects) meant to be consumed by a web browser. This is great for end users who want to see something visually compelling.

# %% [markdown]
# ### The Many Use Cases for APIs
# APIs can actually be used for many things - not just for retrieving information.
# - Twilio has an API that allows you to write a script to call their API to send text messages to people.
# - GitHub has an API for creating new repositories.
# - Many services have an API allowing a computer to automate a task that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ### Limitations of APIs
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# - **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information through their API.
# - **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.

# %% [markdown]
# ##  Summary Article of an Intro to API Class.
#
# https://restful.io/an-introduction-to-api-s-cee90581ca1b
#
# - link to class
# https://zapier.com/learn/apis/

# %% [markdown]
# Dealing with HTTP requests could be a challenging task for any programming language. Python has two built-in modules, urllib and urllib2 to handle these requests but these could be very confusing and the documentation is not clear. This requires the programmer to write a lot of code to make even a simple HTTP request.
#
# To make these things simpler, one easy-to-use third-party library, known as Requests, is available and most developers prefer to use it instead or urllib/urllib2. It is an Apache2 licensed HTTP library powered by urllib3 and httplib.
#
# - **Requests** is add-on library that allows you to send HTTP requests using Python. With this library, you can access content like web page headers, form data, files, and parameters via simple Python commands. It also allows you to access the response data in a simple way.

# %%
# !pip install request
import requests
# Out:
# Collecting request
#   Downloading https://files.pythonhosted.org/packages/f1/27/7cbde262d854aedf217061a97020d66a63163c5c04e0ec02ff98c5d8f44e/request-2019.4.13.tar.gz
# Collecting get (from request)
#   Downloading https://files.pythonhosted.org/packages/3f/ef/bb46f77f7220ac1b7edba0c76d810c89fddb24ddd8c08f337b9b4a618db7/get-2019.4.13.tar.gz
# Collecting post (from request)
#   Downloading https://files.pythonhosted.org/packages/0f/05/bd79da5849ea6a92485ed7029ef97b1b75e55c26bc0ed3a7ec769af666f3/post-2019.4.13.tar.gz
# Requirement already satisfied: setuptools in /Users/maia/anaconda3/lib/python3.7/site-packages (from request) (40.8.0)
# Collecting query_string (from get->request)
#   Downloading https://files.pythonhosted.org/packages/12/3c/412a45daf5bea9b1d06d7de41787ec4168001dfa418db7ec8723356b119f/query-string-2019.4.13.tar.gz
# Collecting public (from query_string->get->request)
#   Downloading https://files.pythonhosted.org/packages/54/4d/b40004cc6c07665e48af22cfe1e631f219bf4282e15fa76a5b6364f6885c/public-2019.4.13.tar.gz
# Building wheels for collected packages: request, get, post, query-string, public
#   Building wheel for request (setup.py) ... done
#   Stored in directory: /Users/maia/Library/Caches/pip/wheels/30/84/5f/484cfba678967ef58c16fce6890925d5c7172622f20111fbfd
#   Building wheel for get (setup.py) ... done
#   Stored in directory: /Users/maia/Library/Caches/pip/wheels/c1/e3/c1/d02c8c58538853e4c9b78cadb74f6d5c5c370b48a69a7271aa
#   Building wheel for post (setup.py) ... done
#   Stored in directory: /Users/maia/Library/Caches/pip/wheels/c3/c3/24/b5c132b537ab380c02d69e6bd4dec1f5db56b5fe19030473d7
#   Building wheel for query-string (setup.py) ... done
#   Stored in directory: /Users/maia/Library/Caches/pip/wheels/d6/a4/78/01b20a9dc224dcc009fab669f7f27b943b8889c5150bd68d8a
#   Building wheel for public (setup.py) ... done
#   Stored in directory: /Users/maia/Library/Caches/pip/wheels/23/7c/6e/f5b4e09d6596c8b8802b347e48f149031e2363368048f1347a
# Successfully built request get post query-string public
# Installing collected packages: public, query-string, get, post, request
# Successfully installed get-2019.4.13 post-2019.4.13 public-2019.4.13 query-string-2019.4.13 request-2019.4.13

# %% [markdown]
# ## The `.get()` Method
#
# Now we have requests library ready in our working environment, we can start making some requests using the `.get()` method as shown below:

# %%
resp = requests.get('https://www.google.com')
type(resp)
# Out:
# requests.models.Response

# %% [markdown]
# GET is by far the most used HTTP method. We can use GET request to retrieve data from any destination.

# %%
#create a GET request from https://api.github.com/events
r = requests.get('https://api.github.com/events')
print(type(r))
r
# Out:
# <class 'requests.models.Response'>
# <Response [200]>

# %% [markdown]
# ## Status Codes
# The request we make may not be always successful. The best way is to check the status code which gets returned with the response. Here is how you would do this.

# %%
# from google
resp.status_code == requests.codes.ok
# Out:
# True

# %% [markdown]
# ## Response Contents

# %%
# text from google
print (resp.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world's information, including webpages, images, videos and more. Google has many special features to help you find exactly what you're looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="AokXiEv+/n5iCitI/zAf4Q==">(function(){window.google={kEI:'fo4wXfy9EoqvggeBuIKIBA',kEXPI:'0,1353804,1958,2422,1225,731,223,510,1065,3152,209,168,207,1017,176,51,508,328,219,202,53,187,463,10,56,175,15,2331142,346,329193,1294,12383,4855,32692,15247,867,12163,5281,1100,853,2482,2,2,6801,363,3320,5505,224,2218,5367,575,1119,2,578,728,2068,363,59,2,1,3,1297,284,3188,851,3700,1267,774,2255,1402,3337,1146,9,1965,2593,1929,1672,669,1050,1808,1397,81,7,1,2,488,2044,7242,1667,4604,590,103,796,101,1120,37,920,754,119,1217,1212,152,1611,2736,49,1509,1503,2,631,3240,46,1769,3011,1161,1447,12,620,2228,655,17,322,234,883,902,105,1048,198,777,1,368,1317,705,756,502,18,399,992,509,598,10,168,8,109,1018,1495,174,967,48,553,11,14,10,657,612,2212,25,177,37,287,4,1245,7,840,324,193,513,18,263,672,18,38,157,663,1464,539,275,135,207,158,176,484,108,152,1187,1,3,7,7,1,2,1492,539,15,606,795,1035,9,2,182,595,943,257,125,377,361,141,184,658,360,243,448,105,194,29,216,184,44,177,30,1,1,893,328,1284,16,84,135,201,81,486,21,1777,82,60,48,1591,608,90,10,25,121,222,5,509,69,136,328,33,4,51,25,22,162,459,41,229,501,60,61,436,406,185,80,1526,72,1,592,232,100,33,14,794,2,223,828,117,2,491,817,292,23,35,404,54,303,284,2,9,76,995,450,1,696,235,99,2,5912451,3010,8797329,4,1572,549,333,444,1,2,80,1,900,583,9,304,1,8,1,2,2132,1,1,1,1,1,414,1,748,141,59,726,3,7,563,1,2850,73,19,42,46,10,12,1,26,24,1,2796915,19507119',authuser:0,kscs:'c9c918f0_fo4wXfy9EoqvggeBuIKIBA',kGL:'US'};google.sn='webhp';google.kHL='en';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.time=function(){return(new Date).getTime()};google.log=function(a,b,e,c,g){if(a=google.logUrl(a,b,e,c,g)){b=new Image;var d=google.lc,f=google.li;d[f]=b;b.onerror=b.onload=b.onabort=function(){delete d[f]};google.vel&&google.vel.lu&&google.vel.lu(a);b.src=a;google.li=f+1}};google.logUrl=function(a,b,e,c,g){var d="",f=google.ls||"";e||-1!=b.search("&ei=")||(d="&ei="+google.getEI(c),-1==b.search("&lei=")&&(c=google.getLEI(c))&&(d+="&lei="+c));c="";!e&&google.cshid&&-1==b.search("&cshid=")&&"slh"!=a&&(c="&cshid="+google.cshid);a=e||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+d+f+"&zx="+google.time()+c;/^http:/i.test(a)&&google.https()&&(google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};var a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decorat ...
# </style><style>body,td,a,p,.h{font-family:arial,sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#36c}.q{color:#00c}.ts td{padding:0}.ts{border-collapse:collapse}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px arial,sans-serif}.gsfs{font:17px arial,sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}a.gb1,a.gb2,a.gb3,a.gb4{color:#11c !important}body{background:#fff;color:black}a{color:#11c;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#36c}a:visited{color:#551a8b}a.gb1,a.gb4{text-decoration:underline}a.gb3:hover{text-decoration:none}#ghead a.gb2:hover{color:#fff !important}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#eee;border:solid 1px;border-color:#ccc #999 #999 #ccc;height:30px}.lsbb{display:block}.ftl,#fll a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;border:none;color:#000;cursor:pointer;height:30px;margin:0;outline:0;font:15px arial,sans-serif;vertical-align:top}.lsb:active{background:#ccc}.lst:focus{outline:none}</style><script nonce="AokXiEv+/n5iCitI/zAf4Q=="></script></head><body bgcolor="#fff"><script nonce="AokXiEv+/n5iCitI/zAf4Q==">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"> <div id=gbar><nobr><b class=gb1>Search</b> <a class=gb1 href="https://www.google.com/imghp?hl=en&tab=wi">Images</a> <a class=gb1 href="https://maps.google.com/maps?hl=en&tab=wl">Maps</a> <a class=gb1 href="https://play.google.com/?hl=en&tab=w8">Play</a> <a class=gb1 href="https://www.youtube.com/?gl=US&tab=w1">YouTube</a> <a class=gb1 href="https://news.google.com/nwshp?hl=en&tab=wn">News</a> <a class=gb1 href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 href="https://drive.google.com/?tab=wo">Drive</a> <a class=gb1 style="text-decoration:none" href="https://www.google.com/intl/en/about/products?tab=wh"><u>More</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a href="http://www.google.com/history/optout?hl=en" class=gb4>Web History</a> | <a  href="/preferences?hl=en" class=gb4>Settings</a> | <a target=_top id=gb_70 href="https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=https://www.google.com/" class=gb4>Sign in</a></nobr></div><div class=gbh style=left:0></div><div class=gbh style=right:0></div> </div><center><br clear="all" id="lgpd"><div id="lga"><img alt="Google" height="92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input name="ie" value="ISO-8859-1" type="hidden"><input value="en" name="hl" type="hidden"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32px;margin:4px 0"><input style="color:#000;margin:0;padding:5px 8px 0 6px;vertical-align:top" autocomplete="off" class="lst" value="" title="Google Search" maxlength="2048" name="q" size="57"></div><br style="line-height:0"><span class="ds"><span class="lsbb"><input class="lsb" value="Google Search" name="btnG" type="submit"></span></span><span class="ds"><span class="lsbb"><input class="lsb" value="I'm Feeling Lucky" name="btnI" onclick="if(this.form.q.value)this.checked=1; else top.location='/doodles/'" type="submit"></span></span></td><td class="fl sblc" align="left" nowrap="" width="25%"><a href="/advanced_search?hl=en&amp;authuser=0">Advanced search</a><a href="/language_tools?hl=en&amp;authuser=0">Language tools</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"><script nonce="AokXiEv+/n5iCitI/zAf4Q==">(function(){var a,b="1";if(document&&document.getElementById)if("undefined"!=typeof XMLHttpRequest)b="2";else if("undefined"!=typeof ActiveXObject){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div id="gac_scont"></div><div style="font-size:83%;min-height:3.5em"><br></div><span id="footer"><div style="font-size:10pt"><div style="margin:19px auto;text-align:center" id="fll"><a href="/intl/en/ads/">Advertising Programs</a><a href="/services/">Business Solutions</a><a href="/intl/en/about.html">About Google</a></div></div><p style="color:#767676;font-size:8pt">&copy; 2019 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="AokXiEv+/n5iCitI/zAf4Q==">(function(){window.google.cdo={height:0,width:0};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}a&&b&&(a!=google.cdo.width||b!=google.cdo.height)&&google.log("","","/client_204?&atyp=i&biw="+a+"&bih="+b+"&e ...
# function _F_installCss(c){}
# (function(){google.spjs=false;google.snet=true;google.em=[];google.emw=false;})();google.sm=1;(function(){var pmc='{\x22Qnk92g\x22:{},\x22RWGcrA\x22:{},\x22U5B21g\x22:{},\x22YFCs/g\x22:{},\x22ZI/YVQ\x22:{},\x22d\x22:{},\x22mVopag\x22:{},\x22sb_he\x22:{\x22agen\x22:true,\x22cgen\x22:true,\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22dhqt\x22:true,\x22ds\x22:\x22\x22,\x22ffql\x22:\x22en\x22,\x22fl\x22:true,\x22host\x22:\x22google.com\x22,\x22isbh\x22:28,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22Clear Search\x22,\x22dym\x22:\x22Did you mean:\x22,\x22lcky\x22:\x22I\\u0026#39;m Feeling Lucky\x22,\x22lml\x22:\x22Learn more\x22,\x22oskt\x22:\x22Input tools\x22,\x22psrc\x22:\x22This search was removed from your \\u003Ca href\x3d\\\x22/history\\\x22\\u003EWeb History\\u003C/a\\u003E\x22,\x22psrl\x22:\x22Remove\x22,\x22sbit\x22:\x22Search by image\x22,\x22srch\x22:\x22Google Search\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22refpd\x22:true,\x22rfs\x22:[],\x22sbpl\x22:24,\x22sbpr\x22:24,\x22scd\x22:10,\x22sce\x22:5,\x22stok\x22:\x22pivQ4eVZbKSaI02p-kRaJj16t44\x22,\x22uhde\x22:false}}';google.pmc=JSON.parse(pmc);})();</script>        </body></html>

# %% [markdown]
# ## Response Headers
# The response of an HTTP request can contain many headers that holds different bits of information. We can use `.header` property of the response object to access the header information as shown below:

# %%
#tell us what is in header index ????

dict(resp.headers)
# Out:
# {'Date': 'Thu, 18 Jul 2019 15:21:34 GMT',
#  'Expires': '-1',
#  'Cache-Control': 'private, max-age=0',
#  'Content-Type': 'text/html; charset=ISO-8859-1',
#  'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."',
#  'Content-Encoding': 'gzip',
#  'Server': 'gws',
#  'X-XSS-Protection': '0',
#  'X-Frame-Options': 'SAMEORIGIN',
#  'Set-Cookie': '1P_JAR=2019-07-18-15; expires=Sat, 17-Aug-2019 15:21:34 GMT; path=/; domain=.google.com, NID=188=qR7xqOil5YAAX99WQ6B6_HOlJsfUyVXUtzg9gbL-Xx1PneBKjrAS5B4MDLCAOo83wU-GKSPMFiEsCBhRDCrcUoWx4lLWITRz-45KBAYfhtdWHIE1WCDasuH7uTenLzgaA7I2EiOBGS9NsydDWghgDeXB_1DGqTXwwIXLlUhQoIk; expires=Fri, 17-Jan-2020 15:21:34 GMT; path=/; domain=.google.com; HttpOnly',
#  'Alt-Svc': 'quic=":443"; ma=2592000; v="46,43,39"',
#  'Transfer-Encoding': 'chunked'}

# %% [markdown]
# ## Passing Parameters in GET
# In some cases, you'll need to pass parameters along with your GET requests. These extra parameters usually take the the form of query strings added to the requested URL. To do this, we need to pass these values in the `params` parameter. Let's try to acces information from `httpbin` with some user information.

# %%
credentials = {'user_name': 'doe', 'password': 'jane'}  
r = requests.get('http://httpbin.org/get', params=credentials)

print(r.url)  
print(r.text)
# Out:
# http://httpbin.org/get?user_name=doe&password=jane
# {
#   "args": {
#     "password": "jane",
#     "user_name": "doe"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.21.0"
#   },
#   "origin": "65.213.153.66, 65.213.153.66",
#   "url": "https://httpbin.org/get?user_name=doe&password=jane"
# }

# %% [markdown]
# ## API EXAMPLE

# %% [markdown]
# Now that we've discussed HTTP requests, it's time to practice applying those skills to a production level API.

# %% [markdown]
# To start, go over to the API documentation at:
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv

# %%
import requests
import pandas as pd

zip_code = '11004'

# can't figure out date ranges at the moment...
start_date = '2018-01-01T12:00:00'
end_date = '2018-02-01T12:00:00'

# create pull request based on parameters
# https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9 click API

#url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json?incident_zip={}".format(zip_code)
url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json"
# do the pull
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
else:
    print('Hit an error.')
    # no print is good

# %%
data
# Out:
# [{'unique_key': '32670008',
#   'created_date': '2016-02-12T19:09:12.000',
#   'closed_date': '2016-02-13T08:53:35.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10462',
#   'incident_address': '1554 UNIONPORT ROAD',
#   'street_name': 'UNIONPORT ROAD',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-13T08:53:35.000',
#   'community_board': '09 BRONX',
#   'bbl': '2039437501',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1023468',
#   'y_coordinate_state_plane': '244401',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.837412497774515',
#   'longitude': '-73.8582699729046',
#   'location': {'type': 'Point',
#    'coordinates': [-73.858269972905, 40.837412497775]},
#   ':@computed_region_efsh_h5xi': '11271',
#   ':@computed_region_f5dn_yrer': '58',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '31',
#   ':@computed_region_sbqj_enih': '26'},
#  {'unique_key': '32670009',
#   'created_date': '2016-02-12T15:13:40.000',
#   'closed_date': '2016-02-15T13:11:44.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11210',
#   'incident_address': '2501 NOSTRAND AVENUE',
#   'street_name': 'NOSTRAND AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-15T13:11:44.000',
#   'community_board': '18 BROOKLYN',
#   'bbl': '3076300027',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '999171',
#   'y_coordinate_state_plane': '166449',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.62352798084708',
#   'longitude': '-73.94624978072031',
#   'location': {'type': 'Point',
#    'coordinates': [-73.94624978072, 40.623527980847]},
#   ':@computed_region_efsh_h5xi': '17217',
#   ':@computed_region_f5dn_yrer': '5',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '26',
#   ':@computed_region_sbqj_enih': '38'},
#  {'unique_key': '32670010',
#   'created_date': '2016-02-13T12:19:57.000',
#   'closed_date': '2016-02-14T13:35:25.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10031',
#   'incident_address': '518 WEST  139 STREET',
#   'street_name': 'WEST  139 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-14T13:35:25.000',
#   'community_board': '09 MANHATTAN',
#   'bbl': '1020700043',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '997767',
#   'y_coordinate_state_plane': '238673',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.821767516762144',
#   'longitude': '-73.95116238375083',
#   'location': {'type': 'Point',
#    'coordinates': [-73.951162383751, 40.821767516762]},
#   ':@computed_region_efsh_h5xi': '12428',
#   ':@computed_region_f5dn_yrer': '37',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '23',
#   ':@computed_region_sbqj_enih': '19'},
#  {'unique_key': '32670011',
#   'created_date': '2016-02-13T09:47:37.000',
#   'closed_date': '2016-02-17T03:00:54.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11203',
#   'incident_address': '541 EAST   52 STREET',
#   'street_name': 'EAST   52 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-17T03:00:54.000',
#   'community_board': '17 BROOKLYN',
#   'bbl': '3047370053',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1004245',
#   'y_coordinate_state_plane': '175133',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.64735370700222',
#   'longitude': '-73.9279458835492',
#   'location': {'type': 'Point',
#    'coordinates': [-73.927945883549, 40.647353707002]},
#   ':@computed_region_efsh_h5xi': '16866',
#   ':@computed_region_f5dn_yrer': '61',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '26',
#   ':@computed_region_sbqj_enih': '40'},
#  {'unique_key': '32670012',
#   'created_date': '2016-02-12T12:35:10.000',
#   'closed_date': '2016-02-15T20:07:13.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10460',
#   'incident_address': '900 BRONX PARK SOUTH',
#   'street_name': 'BRONX PARK SOUTH',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development inspected the following conditions. No violations were issued. The complaint has been closed.',
#   'resolution_action_updated_date': '2016-02-15T20:07:13.000',
#   'community_board': '06 BRONX',
#   'bbl': '2031250040',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1017180',
#   'y_coordinate_state_plane': '247713',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.84652864759396',
#   'longitude': '-73.88097789789056',
#   'location': {'type': 'Point',
#    'coordinates': [-73.880977897891, 40.846528647594]},
#   ':@computed_region_efsh_h5xi': '11269',
#   ':@computed_region_f5dn_yrer': '35',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '22',
#   ':@computed_region_sbqj_enih': '31'},
#  {'unique_key': '32670013',
#   'created_date': '2016-02-13T08:08:09.000',
#   'closed_date': '2016-02-16T15:28:08.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10035',
#   'incident_address': '1428 5 AVENUE',
#   'street_name': '5 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-16T15:28:08.000',
#   'community_board': '10 MANHATTAN',
#   'bbl': '1016000021',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '999167',
#   'y_coordinate_state_plane': '231162',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.8011496612852',
#   'longitude': '-73.94612080473502',
#   'location': {'type': 'Point',
#    'coordinates': [-73.946120804735, 40.801149661285]},
#   ':@computed_region_efsh_h5xi': '12423',
#   ':@computed_region_f5dn_yrer': '18',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '36',
#   ':@computed_region_sbqj_enih': '18'},
#  {'unique_key': '32670017',
#   'created_date': '2016-02-14T01:50:48.000',
#   'closed_date': '2016-04-25T14:44:24.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'Taxi Complaint',
#   'descriptor': 'Driver Complaint',
#   'incident_zip': '10025',
#   'intersection_street_1': 'WEST   97 STREET',
#   'intersection_street_2': 'COLUMBUS AVENUE',
#   'address_type': 'INTERSECTION',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'due_date': '2016-04-01T09:26:50.000',
#   'resolution_description': 'Based on the information provided by the customer, the Taxi and Limousine Commission has determined that a hearing is not necessary or not possible.',
#   'resolution_action_updated_date': '2016-04-25T14:44:24.000',
#   'community_board': '07 MANHATTAN',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '993383',
#   'y_coordinate_state_plane': '228393',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': 'Other',
#   'latitude': '40.79355738131325',
#   'longitude': '-73.96701598496212',
#   'location': {'type': 'Point',
#    'coordinates': [-73.967015984962, 40.793557381313]},
#   ':@computed_region_efsh_h5xi': '12422',
#   ':@computed_region_f5dn_yrer': '20',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '23',
#   ':@computed_region_sbqj_enih': '15'},
#  {'unique_key': '32670021',
#   'created_date': '2016-02-13T20:49:26.000',
#   'closed_date': '2016-02-18T01:11:49.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11210',
#   'incident_address': '3101 AVENUE I',
#   'street_name': 'AVENUE I',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development responded to a complaint of no heat or hot water and was advised by a tenant in the building that heat and hot water had been restored. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-18T01:11:49.000',
#   'community_board': '14 BROOKLYN',
#   'bbl': '3075770006',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '999186',
#   'y_coordinate_state_plane': '168552',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.629300247816936',
#   'longitude': '-73.9461910923712',
#   'location': {'type': 'Point',
#    'coordinates': [-73.946191092371, 40.629300247817]},
#   ':@computed_region_efsh_h5xi': '17217',
#   ':@computed_region_f5dn_yrer': '60',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '26',
#   ':@computed_region_sbqj_enih': '43'},
#  {'unique_key': '32670022',
#   'created_date': '2016-02-12T09:43:39.000',
#   'closed_date': '2016-02-16T22:09:32.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11368',
#   'incident_address': '97-07 HORACE HARDING EXPRESSWAY',
#   'street_name': 'HORACE HARDING EXPRESSWAY',
#   'address_type': 'ADDRESS',
#   'city': 'Corona',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-16T22:09:32.000',
#   'community_board': '04 QUEENS',
#   'bbl': '4019180110',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1022356',
#   'y_coordinate_state_plane': '207053',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.73490722205727',
#   'longitude': '-73.86250048829798',
#   'location': {'type': 'Point',
#    'coordinates': [-73.862500488298, 40.734907222057]},
#   ':@computed_region_efsh_h5xi': '14510',
#   ':@computed_region_f5dn_yrer': '66',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '21',
#   ':@computed_region_sbqj_enih': '68'},
#  {'unique_key': '32670023',
#   'created_date': '2016-02-13T19:05:31.000',
#   'closed_date': '2016-02-15T18:37:16.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10028',
#   'incident_address': '128 EAST   86 STREET',
#   'street_name': 'EAST   86 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-15T18:37:16.000',
#   'community_board': '08 MANHATTAN',
#   'bbl': '1015140058',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '996435',
#   'y_coordinate_state_plane': '223333',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.77966535432971',
#   'longitude': '-73.95600280515514',
#   'location': {'type': 'Point',
#    'coordinates': [-73.956002805155, 40.77966535433]},
#   ':@computed_region_efsh_h5xi': '12425',
#   ':@computed_region_f5dn_yrer': '23',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '51',
#   ':@computed_region_sbqj_enih': '11'},
#  {'unique_key': '32670024',
#   'created_date': '2016-02-12T13:03:33.000',
#   'closed_date': '2016-02-16T18:00:51.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11225',
#   'incident_address': '1086 PRESIDENT STREET',
#   'street_name': 'PRESIDENT STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development responded to a complaint of no heat or hot water and was advised by a tenant in the building that heat and hot water had been restored. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-16T18:00:51.000',
#   'community_board': '09 BROOKLYN',
#   'bbl': '3012810017',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '996744',
#   'y_coordinate_state_plane': '182759',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.66829915852707',
#   'longitude': '-73.95496240214968',
#   'location': {'type': 'Point',
#    'coordinates': [-73.95496240215, 40.668299158527]},
#   ':@computed_region_efsh_h5xi': '13509',
#   ':@computed_region_f5dn_yrer': '17',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '48',
#   ':@computed_region_sbqj_enih': '44'},
#  {'unique_key': '32670025',
#   'created_date': '2016-02-13T18:11:01.000',
#   'closed_date': '2016-02-20T01:13:10.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10451',
#   'incident_address': '109 EAST  153 STREET',
#   'street_name': 'EAST  153 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-20T01:13:10.000',
#   'community_board': '04 BRONX',
#   'bbl': '2024820001',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1004168',
#   'y_coordinate_state_plane': '239466',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.823931962072784',
#   'longitude': '-73.92803289633304',
#   'location': {'type': 'Point',
#    'coordinates': [-73.928032896333, 40.823931962073]},
#   ':@computed_region_efsh_h5xi': '10929',
#   ':@computed_region_f5dn_yrer': '50',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_sbqj_enih': '27'},
#  {'unique_key': '32670026',
#   'created_date': '2016-02-12T11:11:09.000',
#   'closed_date': '2016-02-13T01:18:06.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11201',
#   'incident_address': '149 WILLOW STREET',
#   'street_name': 'WILLOW STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': "The Department of Housing Preservation and Development has closed this complaint administratively. More information can be found through HPD's website at www.nyc.gov/hpd by using HPDONLINE (enter your address on the home page) and entering your SR number under the complaint status option.",
#   'resolution_action_updated_date': '2016-02-13T01:18:06.000',
#   'community_board': '02 BROOKLYN',
#   'bbl': '3002350015',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '985342',
#   'y_coordinate_state_plane': '193153',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.696837070382415',
#   'longitude': '-73.99606194123623',
#   'location': {'type': 'Point',
#    'coordinates': [-73.996061941236, 40.696837070382]},
#   ':@computed_region_efsh_h5xi': '16865',
#   ':@computed_region_f5dn_yrer': '68',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '38',
#   ':@computed_region_sbqj_enih': '54'},
#  {'unique_key': '32670027',
#   'created_date': '2016-02-12T13:13:38.000',
#   'closed_date': '2016-02-17T11:19:49.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10017',
#   'incident_address': '884 2 AVENUE',
#   'street_name': '2 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-17T11:19:49.000',
#   'community_board': '06 MANHATTAN',
#   'bbl': '1013400001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '992614',
#   'y_coordinate_state_plane': '213649',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.75308972484828',
#   'longitude': '-73.9698115946612',
#   'location': {'type': 'Point',
#    'coordinates': [-73.969811594661, 40.753089724848]},
#   ':@computed_region_efsh_h5xi': '12079',
#   ':@computed_region_f5dn_yrer': '71',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '51',
#   ':@computed_region_sbqj_enih': '9'},
#  {'unique_key': '32670029',
#   'created_date': '2016-02-13T18:34:56.000',
#   'closed_date': '2016-02-18T10:48:38.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10456',
#   'incident_address': '1451 PROSPECT AVENUE',
#   'street_name': 'PROSPECT AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-18T10:48:38.000',
#   'community_board': '03 BRONX',
#   'bbl': '2029370045',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1012773',
#   'y_coordinate_state_plane': '243245',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.834280633282596',
#   'longitude': '-73.89692553326749',
#   'location': {'type': 'Point',
#    'coordinates': [-73.896925533267, 40.834280633283]},
#   ':@computed_region_efsh_h5xi': '10934',
#   ':@computed_region_f5dn_yrer': '34',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '42',
#   ':@computed_region_sbqj_enih': '25'},
#  {'unique_key': '32670030',
#   'created_date': '2016-02-13T10:44:03.000',
#   'agency': 'DPR',
#   'agency_name': 'Department of Parks and Recreation',
#   'complaint_type': 'New Tree Request',
#   'descriptor': 'For One Address',
#   'location_type': 'Street',
#   'incident_zip': '11428',
#   'incident_address': '92-24 218 PLACE',
#   'street_name': '218 PLACE',
#   'cross_street_1': '92 AVENUE',
#   'cross_street_2': '93 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'QUEENS VILLAGE',
#   'facility_type': 'N/A',
#   'status': 'Assigned',
#   'due_date': '2016-08-14T08:52:50.000',
#   'resolution_description': 'The Department of Parks and Recreation has reviewed this request and will visit the location to investigate the condition.',
#   'resolution_action_updated_date': '2016-02-16T08:53:39.000',
#   'community_board': '13 QUEENS',
#   'bbl': '4107010019',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1056324',
#   'y_coordinate_state_plane': '202828',
#   'open_data_channel_type': 'OTHER',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.72309910572502',
#   'longitude': '-73.7399781031915',
#   'location': {'type': 'Point',
#    'coordinates': [-73.739978103191, 40.723099105725]},
#   ':@computed_region_efsh_h5xi': '24337',
#   ':@computed_region_f5dn_yrer': '63',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '16',
#   ':@computed_region_sbqj_enih': '63'},
#  {'unique_key': '32670032',
#   'created_date': '2016-02-13T13:54:53.000',
#   'closed_date': '2016-02-14T13:03:10.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10010',
#   'incident_address': '152 EAST   22 STREET',
#   'street_name': 'EAST   22 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-14T13:03:10.000',
#   'community_board': '06 MANHATTAN',
#   'bbl': '1008770053',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '988501',
#   'y_coordinate_state_plane': '208365',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.738589403711345',
#   'longitude': '-73.98466009317058',
#   'location': {'type': 'Point',
#    'coordinates': [-73.984660093171, 40.738589403711]},
#   ':@computed_region_efsh_h5xi': '12073',
#   ':@computed_region_f5dn_yrer': '71',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '50',
#   ':@computed_region_sbqj_enih': '7'},
#  {'unique_key': '32670033',
#   'created_date': '2016-02-13T19:03:14.000',
#   'closed_date': '2016-02-14T01:20:55.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11230',
#   'incident_address': '1026 EAST   15 STREET',
#   'street_name': 'EAST   15 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-14T01:20:55.000',
#   'community_board': '14 BROOKLYN',
#   'bbl': '3067160015',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '995006',
#   'y_coordinate_state_plane': '166756',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.624376667247915',
#   'longitude': '-73.96125295271864',
#   'location': {'type': 'Point',
#    'coordinates': [-73.961252952719, 40.624376667248]},
#   ':@computed_region_efsh_h5xi': '13513',
#   ':@computed_region_f5dn_yrer': '60',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '18',
#   ':@computed_region_sbqj_enih': '43'},
#  {'unique_key': '32670034',
#   'created_date': '2016-02-13T19:03:09.000',
#   'closed_date': '2016-02-19T08:27:40.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11426',
#   'incident_address': '247-20 89 AVENUE',
#   'street_name': '89 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'Bellerose',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-19T08:27:40.000',
#   'community_board': '13 QUEENS',
#   'bbl': '4086630013',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1061727',
#   'y_coordinate_state_plane': '204344',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.72721446569076',
#   'longitude': '-73.72046833530877',
#   'location': {'type': 'Point',
#    'coordinates': [-73.720468335309, 40.727214465691]},
#   ':@computed_region_efsh_h5xi': '24335',
#   ':@computed_region_f5dn_yrer': '63',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '16',
#   ':@computed_region_sbqj_enih': '63'},
#  {'unique_key': '32670074',
#   'created_date': '2016-02-13T14:18:44.000',
#   'closed_date': '2016-02-13T19:29:49.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Vehicle',
#   'descriptor': 'Engine Idling',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11206',
#   'incident_address': '56 STAGG STREET',
#   'street_name': 'STAGG STREET',
#   'cross_street_1': 'LORIMER STREET',
#   'cross_street_2': 'LEONARD STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-13T22:18:44.000',
#   'resolution_description': 'The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.',
#   'resolution_action_updated_date': '2016-02-13T19:29:49.000',
#   'community_board': '01 BROOKLYN',
#   'bbl': '3030320005',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '998664',
#   'y_coordinate_state_plane': '197610',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.70905881594053',
#   'longitude': '-73.94800953318133',
#   'location': {'type': 'Point',
#    'coordinates': [-73.948009533181, 40.709058815941]},
#   ':@computed_region_efsh_h5xi': '17213',
#   ':@computed_region_f5dn_yrer': '36',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '30',
#   ':@computed_region_sbqj_enih': '56'},
#  {'unique_key': '32670035',
#   'created_date': '2016-02-13T17:45:02.000',
#   'closed_date': '2016-02-17T16:50:38.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10452',
#   'incident_address': '22 ELLIOT PLACE',
#   'street_name': 'ELLIOT PLACE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-17T16:50:38.000',
#   'community_board': '04 BRONX',
#   'bbl': '2028410014',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1007065',
#   'y_coordinate_state_plane': '245093',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.83936944606976',
#   'longitude': '-73.91754641355783',
#   'location': {'type': 'Point',
#    'coordinates': [-73.917546413558, 40.83936944607]},
#   ':@computed_region_efsh_h5xi': '10930',
#   ':@computed_region_f5dn_yrer': '50',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '42',
#   ':@computed_region_sbqj_enih': '27'},
#  {'unique_key': '32670036',
#   'created_date': '2016-02-12T10:20:45.000',
#   'closed_date': '2016-02-13T18:14:17.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'PAINT/PLASTER',
#   'descriptor': 'WALL',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11225',
#   'incident_address': '55 WINTHROP STREET',
#   'street_name': 'WINTHROP STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development inspected the following conditions. Violations were previously issued for these conditions. Information about specific violations is available at www.nyc.gov/hpd.',
#   'resolution_action_updated_date': '2016-02-13T18:14:17.000',
#   'community_board': '09 BROOKLYN',
#   'bbl': '3050450078',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '995885',
#   'y_coordinate_state_plane': '178504',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.65662129596871',
#   'longitude': '-73.95806621423951',
#   'location': {'type': 'Point',
#    'coordinates': [-73.95806621424, 40.656621295969]},
#   ':@computed_region_efsh_h5xi': '13509',
#   ':@computed_region_f5dn_yrer': '17',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '11',
#   ':@computed_region_sbqj_enih': '44'},
#  {'unique_key': '32670038',
#   'created_date': '2016-02-12T17:26:43.000',
#   'closed_date': '2016-02-16T09:27:16.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10455',
#   'incident_address': '547 CAULDWELL AVENUE',
#   'street_name': 'CAULDWELL AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development inspected the following conditions. No violations were issued. The complaint has been closed.',
#   'resolution_action_updated_date': '2016-02-16T09:27:16.000',
#   'community_board': '01 BRONX',
#   'bbl': '2026230060',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1008929',
#   'y_coordinate_state_plane': '235834',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.81395113045769',
#   'longitude': '-73.9108439651691',
#   'location': {'type': 'Point',
#    'coordinates': [-73.910843965169, 40.813951130458]},
#   ':@computed_region_efsh_h5xi': '10933',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '43',
#   ':@computed_region_sbqj_enih': '23'},
#  {'unique_key': '32670039',
#   'created_date': '2016-02-13T11:10:00.000',
#   'closed_date': '2016-02-16T11:41:55.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10032',
#   'incident_address': '3851 BROADWAY',
#   'street_name': 'BROADWAY',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development inspected the following conditions. No violations were issued. The complaint has been closed.',
#   'resolution_action_updated_date': '2016-02-16T11:41:55.000',
#   'community_board': '12 MANHATTAN',
#   'bbl': '1021370014',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '999947',
#   'y_coordinate_state_plane': '243959',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.836272466705225',
#   'longitude': '-73.9432735657598',
#   'location': {'type': 'Point',
#    'coordinates': [-73.94327356576, 40.836272466705]},
#   ':@computed_region_efsh_h5xi': '13090',
#   ':@computed_region_f5dn_yrer': '47',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '23',
#   ':@computed_region_sbqj_enih': '21'},
#  {'unique_key': '32670040',
#   'created_date': '2016-02-13T09:36:04.000',
#   'closed_date': '2016-02-21T14:32:32.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11236',
#   'incident_address': '1222 EAST   83 STREET',
#   'street_name': 'EAST   83 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development responded to a complaint of no heat or hot water and was advised by a tenant in the building that heat and hot water had been restored. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-21T14:32:32.000',
#   'community_board': '18 BROOKLYN',
#   'bbl': '3080610052',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1010604',
#   'y_coordinate_state_plane': '169366',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.63150789470168',
#   'longitude': '-73.90505308984183',
#   'location': {'type': 'Point',
#    'coordinates': [-73.905053089842, 40.631507894702]},
#   ':@computed_region_efsh_h5xi': '13827',
#   ':@computed_region_f5dn_yrer': '5',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '8',
#   ':@computed_region_sbqj_enih': '42'},
#  {'unique_key': '32670041',
#   'created_date': '2016-02-12T20:38:45.000',
#   'closed_date': '2016-02-16T01:08:25.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10022',
#   'incident_address': '155 EAST   52 STREET',
#   'street_name': 'EAST   52 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-16T01:08:25.000',
#   'community_board': '06 MANHATTAN',
#   'bbl': '1013070029',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '992317',
#   'y_coordinate_state_plane': '215262',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.75751727517092',
#   'longitude': '-73.97088162924723',
#   'location': {'type': 'Point',
#    'coordinates': [-73.970881629247, 40.757517275171]},
#   ':@computed_region_efsh_h5xi': '12419',
#   ':@computed_region_f5dn_yrer': '71',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '51',
#   ':@computed_region_sbqj_enih': '9'},
#  {'unique_key': '32670042',
#   'created_date': '2016-02-12T23:39:37.000',
#   'closed_date': '2016-02-16T00:00:00.000',
#   'agency': 'DOB',
#   'agency_name': 'Department of Buildings',
#   'complaint_type': 'General Construction/Plumbing',
#   'descriptor': 'Working Contrary To Stop Work Order',
#   'incident_zip': '11205',
#   'incident_address': '168 FRANKLIN AVENUE',
#   'street_name': 'FRANKLIN AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Buildings determined that the conditions described in this complaint were addressed under another service request number. Click on "Learn More" in the "Did You Know" section below for more information.',
#   'resolution_action_updated_date': '2016-02-16T00:00:00.000',
#   'community_board': '03 BROOKLYN',
#   'bbl': '3019120040',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '995938',
#   'y_coordinate_state_plane': '191975',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.6935960830597',
#   'longitude': '-73.95785183589834',
#   'location': {'type': 'Point',
#    'coordinates': [-73.957851835898, 40.69359608306]},
#   ':@computed_region_efsh_h5xi': '17212',
#   ':@computed_region_f5dn_yrer': '69',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '38',
#   ':@computed_region_sbqj_enih': '51'},
#  {'unique_key': '32670043',
#   'created_date': '2016-02-12T19:41:03.000',
#   'closed_date': '2016-02-15T18:45:53.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10455',
#   'incident_address': '640 WALES AVENUE',
#   'street_name': 'WALES AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development inspected the following conditions. No violations were issued. The complaint has been closed.',
#   'resolution_action_updated_date': '2016-02-15T18:45:53.000',
#   'community_board': '01 BRONX',
#   'bbl': '2026530063',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1010158',
#   'y_coordinate_state_plane': '236279',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.81516901161363',
#   'longitude': '-73.90640233149193',
#   'location': {'type': 'Point',
#    'coordinates': [-73.906402331492, 40.815169011614]},
#   ':@computed_region_efsh_h5xi': '10933',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_sbqj_enih': '23'},
#  {'unique_key': '32670044',
#   'created_date': '2016-02-12T06:47:23.000',
#   'closed_date': '2016-02-14T11:00:14.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11236',
#   'incident_address': '1044 EAST   96 STREET',
#   'street_name': 'EAST   96 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-14T11:00:14.000',
#   'community_board': '18 BROOKLYN',
#   'bbl': '3081640265',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1010916',
#   'y_coordinate_state_plane': '174402',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.645329697110554',
#   'longitude': '-73.90390912962253',
#   'location': {'type': 'Point',
#    'coordinates': [-73.903909129623, 40.645329697111]},
#   ':@computed_region_efsh_h5xi': '13827',
#   ':@computed_region_f5dn_yrer': '5',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '8',
#   ':@computed_region_sbqj_enih': '42'},
#  {'unique_key': '32670045',
#   'created_date': '2016-02-13T13:11:35.000',
#   'closed_date': '2016-02-15T12:15:53.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10456',
#   'incident_address': '972 SHERMAN AVENUE',
#   'street_name': 'SHERMAN AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#   'resolution_action_updated_date': '2016-02-15T12:15:53.000',
#   'community_board': '04 BRONX',
#   'bbl': '2024460015',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1006682',
#   'y_coordinate_state_plane': '241136',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.82850960779871',
#   'longitude': '-73.91894381049431',
#   'location': {'type': 'Point',
#    'coordinates': [-73.918943810494, 40.828509607799]},
#   ':@computed_region_efsh_h5xi': '10934',
#   ':@computed_region_f5dn_yrer': '50',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '42',
#   ':@computed_region_sbqj_enih': '27'},
#  {'unique_key': '32670046',
#   'created_date': '2016-02-13T09:42:59.000',
#   'closed_date': '2016-02-22T09:35:49.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '11203',
#   'incident_address': '192 EAST   56 STREET',
#   'street_name': 'EAST   56 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-22T09:35:49.000',
#   'community_board': '17 BROOKLYN',
#   'bbl': '3047030011',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1005171',
#   'y_coordinate_state_plane': '176847',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.65205612420425',
#   'longitude': '-73.92460362905013',
#   'location': {'type': 'Point',
#    'coordinates': [-73.92460362905, 40.652056124204]},
#   ':@computed_region_efsh_h5xi': '16866',
#   ':@computed_region_f5dn_yrer': '61',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '17',
#   ':@computed_region_sbqj_enih': '40'},
#  {'unique_key': '32670047',
#   'created_date': '2016-02-13T23:32:08.000',
#   'closed_date': '2016-02-18T01:08:07.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'HEAT/HOT WATER',
#   'descriptor': 'APARTMENT ONLY',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10039',
#   'incident_address': '287 WEST  147 STREET',
#   'street_name': 'WEST  147 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development responded to a complaint of no heat or hot water and was advised by a tenant in the building that heat and hot water had been restored. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-18T01:08:07.000',
#   'community_board': '10 MANHATTAN',
#   'bbl': '1020330009',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '1000769',
#   'y_coordinate_state_plane': '239439',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.82386486541371',
#   'longitude': '-73.94031412064453',
#   'location': {'type': 'Point',
#    'coordinates': [-73.940314120645, 40.823864865414]},
#   ':@computed_region_efsh_h5xi': '13097',
#   ':@computed_region_f5dn_yrer': '18',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '36',
# ...
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Hydrant',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11419',
#   'incident_address': '101-23 110 STREET',
#   'street_name': '110 STREET',
#   'cross_street_1': '101 AVENUE',
#   'cross_street_2': '103 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'SOUTH RICHMOND HILL',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-14T05:14:22.000',
#   'resolution_description': 'The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.',
#   'resolution_action_updated_date': '2016-02-13T23:00:04.000',
#   'community_board': '09 QUEENS',
#   'bbl': '4094280066',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1030457',
#   'y_coordinate_state_plane': '189788',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.687480375236454',
#   'longitude': '-73.83338785973302',
#   'location': {'type': 'Point',
#    'coordinates': [-73.833387859733, 40.687480375236]},
#   ':@computed_region_efsh_h5xi': '24015',
#   ':@computed_region_f5dn_yrer': '46',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '46',
#   ':@computed_region_sbqj_enih': '60'},
#  {'unique_key': '32671047',
#   'created_date': '2016-02-13T15:27:00.000',
#   'closed_date': '2016-02-14T15:27:00.000',
#   'agency': 'DEP',
#   'agency_name': 'Department of Environmental Protection',
#   'complaint_type': 'Lead',
#   'descriptor': 'Lead Kit Request (Residential) (L10)',
#   'incident_zip': '10306',
#   'incident_address': '136 BACHE AVENUE',
#   'street_name': 'BACHE AVENUE',
#   'cross_street_1': 'EDISON ST',
#   'cross_street_2': 'CLAWSON ST',
#   'address_type': 'ADDRESS',
#   'city': 'STATEN ISLAND',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Environmental Protection investigated this complaint and created a Service Request to have a Lead Test Kit sent to the complainant.',
#   'resolution_action_updated_date': '2016-02-17T14:49:00.000',
#   'community_board': '02 STATEN ISLAND',
#   'bbl': '5036420053',
#   'borough': 'STATEN ISLAND',
#   'x_coordinate_state_plane': '953280',
#   'y_coordinate_state_plane': '148087',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'STATEN ISLAND',
#   'latitude': '40.573086478662226',
#   'longitude': '-74.11147962976192',
#   'location': {'type': 'Point',
#    'coordinates': [-74.111479629762, 40.573086478662]},
#   ':@computed_region_efsh_h5xi': '10693',
#   ':@computed_region_f5dn_yrer': '30',
#   ':@computed_region_yeji_bk3q': '1',
#   ':@computed_region_92fq_4b7q': '14',
#   ':@computed_region_sbqj_enih': '76'},
#  {'unique_key': '32671048',
#   'created_date': '2016-02-13T16:22:59.000',
#   'closed_date': '2016-02-13T17:02:45.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Sidewalk',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11378',
#   'incident_address': '61-50 56 AVENUE',
#   'street_name': '56 AVENUE',
#   'cross_street_1': '61 STREET',
#   'cross_street_2': '64 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'MASPETH',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-14T00:22:59.000',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'resolution_action_updated_date': '2016-02-13T17:02:45.000',
#   'community_board': '05 QUEENS',
#   'bbl': '4027090065',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1010894',
#   'y_coordinate_state_plane': '203441',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.72503512725655',
#   'longitude': '-73.90387357577295',
#   'location': {'type': 'Point',
#    'coordinates': [-73.903873575773, 40.725035127257]},
#   ':@computed_region_efsh_h5xi': '14788',
#   ':@computed_region_f5dn_yrer': '54',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '34',
#   ':@computed_region_sbqj_enih': '62'},
#  {'unique_key': '32671049',
#   'created_date': '2016-02-13T21:49:58.000',
#   'closed_date': '2016-02-13T23:01:09.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Commercial Overnight Parking',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11360',
#   'intersection_street_1': 'CLEARVIEW EXPRESSWAY SR SB',
#   'intersection_street_2': '29 AVENUE',
#   'address_type': 'INTERSECTION',
#   'city': 'BAYSIDE',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-14T05:49:58.000',
#   'resolution_description': 'The Police Department issued a summons in response to the complaint.',
#   'resolution_action_updated_date': '2016-02-13T23:01:09.000',
#   'community_board': '11 QUEENS',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1043869',
#   'y_coordinate_state_plane': '221167',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.77352760060412',
#   'longitude': '-73.78474932071872',
#   'location': {'type': 'Point',
#    'coordinates': [-73.784749320719, 40.773527600604]},
#   ':@computed_region_efsh_h5xi': '14195',
#   ':@computed_region_f5dn_yrer': '26',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '20',
#   ':@computed_region_sbqj_enih': '69'},
#  {'unique_key': '32671050',
#   'created_date': '2016-02-12T08:54:03.000',
#   'closed_date': '2016-02-14T13:53:06.000',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'complaint_type': 'SAFETY',
#   'descriptor': 'CARBON MONOXIDE DETECTOR',
#   'location_type': 'RESIDENTIAL BUILDING',
#   'incident_zip': '10453',
#   'incident_address': '1805 PHELAN PLACE',
#   'street_name': 'PHELAN PLACE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new complaint.',
#   'resolution_action_updated_date': '2016-02-14T13:53:06.000',
#   'community_board': '05 BRONX',
#   'bbl': '2028790139',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1007159',
#   'y_coordinate_state_plane': '249844',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.85240929544965',
#   'longitude': '-73.917190465335',
#   'location': {'type': 'Point',
#    'coordinates': [-73.917190465335, 40.85240929545]},
#   ':@computed_region_efsh_h5xi': '10931',
#   ':@computed_region_f5dn_yrer': '6',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '29',
#   ':@computed_region_sbqj_enih': '29'},
#  {'unique_key': '32671051',
#   'created_date': '2016-02-13T20:51:25.000',
#   'closed_date': '2016-02-13T23:24:55.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Commercial',
#   'descriptor': 'Loud Television',
#   'location_type': 'Store/Commercial',
#   'incident_zip': '11211',
#   'incident_address': '507 GRAND STREET',
#   'street_name': 'GRAND STREET',
#   'cross_street_1': 'UNION AVENUE',
#   'cross_street_2': 'LORIMER STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-14T04:51:25.000',
#   'resolution_description': 'The Police Department responded to the complaint and determined that police action was not necessary.',
#   'resolution_action_updated_date': '2016-02-13T23:24:56.000',
#   'community_board': '01 BROOKLYN',
#   'bbl': '3027790049',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '997936',
#   'y_coordinate_state_plane': '198321',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.711011497957074',
#   'longitude': '-73.95063394136774',
#   'location': {'type': 'Point',
#    'coordinates': [-73.950633941368, 40.711011497957]},
#   ':@computed_region_efsh_h5xi': '17613',
#   ':@computed_region_f5dn_yrer': '36',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '30',
#   ':@computed_region_sbqj_enih': '56'},
#  {'unique_key': '32671052',
#   'created_date': '2016-02-13T18:18:00.000',
#   'closed_date': '2016-02-23T14:20:00.000',
#   'agency': 'DEP',
#   'agency_name': 'Department of Environmental Protection',
#   'complaint_type': 'Noise',
#   'descriptor': 'Noise: Alarms (NR3)',
#   'incident_zip': '11215',
#   'incident_address': '1 JACKSON PLACE',
#   'street_name': 'JACKSON PLACE',
#   'cross_street_1': '16 ST',
#   'cross_street_2': 'PROSPECT AVE',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Environmental Protection did not observe a violation of the New York City Air/Noise Code at the time of inspection and could not issue a notice of violation. If the problem still exists, please call 311 and file a new complaint. If you are outside of New York City, please call (212) NEW-YORK (212-639-9675).',
#   'resolution_action_updated_date': '2016-02-23T14:20:00.000',
#   'community_board': '07 BROOKLYN',
#   'bbl': '3010560019',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '988126',
#   'y_coordinate_state_plane': '180785',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.6628889343073',
#   'longitude': '-73.98602916889016',
#   'location': {'type': 'Point',
#    'coordinates': [-73.98602916889, 40.662888934307]},
#   ':@computed_region_efsh_h5xi': '17617',
#   ':@computed_region_f5dn_yrer': '9',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '27',
#   ':@computed_region_sbqj_enih': '45'},
#  {'unique_key': '32671053',
#   'created_date': '2016-02-13T16:37:00.000',
#   'closed_date': '2016-02-18T13:45:00.000',
#   'agency': 'DEP',
#   'agency_name': 'Department of Environmental Protection',
#   'complaint_type': 'Noise',
#   'descriptor': 'Noise: Alarms (NR3)',
#   'incident_zip': '10014',
#   'incident_address': '2 CHARLTON STREET',
#   'street_name': 'CHARLTON STREET',
#   'cross_street_1': 'AVENUE OF THE AMERICAS',
#   'cross_street_2': 'VARICK ST',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Environmental Protection did not observe a violation of the New York City Air/Noise Code at the time of inspection and could not issue a notice of violation. If the problem still exists, please call 311 and file a new complaint. If you are outside of New York City, please call (212) NEW-YORK (212-639-9675).',
#   'resolution_action_updated_date': '2016-02-18T13:45:00.000',
#   'community_board': '02 MANHATTAN',
#   'bbl': '1005060027',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983207',
#   'y_coordinate_state_plane': '204135',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7269800530374',
#   'longitude': '-74.00376305233803',
#   'location': {'type': 'Point',
#    'coordinates': [-74.003763052338, 40.726980053037]},
#   ':@computed_region_efsh_h5xi': '12077',
#   ':@computed_region_f5dn_yrer': '57',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '10',
#   ':@computed_region_sbqj_enih': '1'},
#  {'unique_key': '32671054',
#   'created_date': '2016-02-13T21:29:42.000',
#   'closed_date': '2016-02-13T23:04:26.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '11237',
#   'incident_address': '143 STARR STREET',
#   'street_name': 'STARR STREET',
#   'cross_street_1': 'KNICKERBOCKER AVENUE',
#   'cross_street_2': 'IRVING AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-14T05:29:42.000',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'resolution_action_updated_date': '2016-02-13T23:04:26.000',
#   'community_board': '04 BROOKLYN',
#   'bbl': '3031870050',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1005103',
#   'y_coordinate_state_plane': '195566',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.70343568768109',
#   'longitude': '-73.92479077109456',
#   'location': {'type': 'Point',
#    'coordinates': [-73.924790771095, 40.703435687681]},
#   ':@computed_region_efsh_h5xi': '13828',
#   ':@computed_region_f5dn_yrer': '42',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '30',
#   ':@computed_region_sbqj_enih': '53'},
#  {'unique_key': '32671055',
#   'created_date': '2016-02-13T20:42:28.000',
#   'closed_date': '2016-02-13T23:08:47.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10454',
#   'incident_address': '342 ALEXANDER AVENUE',
#   'street_name': 'ALEXANDER AVENUE',
#   'cross_street_1': 'EAST 141 STREET',
#   'cross_street_2': 'EAST 142 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-14T04:42:28.000',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'resolution_action_updated_date': '2016-02-13T23:08:47.000',
#   'community_board': '01 BRONX',
#   'bbl': '2023040001',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1005490',
#   'y_coordinate_state_plane': '235333',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.812584963413585',
#   'longitude': '-73.92326936977881',
#   'location': {'type': 'Point',
#    'coordinates': [-73.923269369779, 40.812584963414]},
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_sbqj_enih': '23'},
#  {'unique_key': '32671056',
#   'created_date': '2016-02-13T19:07:11.000',
#   'closed_date': '2016-02-13T21:06:34.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Posted Parking Sign Violation',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10464',
#   'incident_address': '115 ROCHELLE STREET',
#   'street_name': 'ROCHELLE STREET',
#   'cross_street_1': 'DEAD END',
#   'cross_street_2': 'CITY ISLAND AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2016-02-14T03:07:11.000',
#   'resolution_description': 'The Police Department issued a summons in response to the complaint.',
#   'resolution_action_updated_date': '2016-02-13T21:06:34.000',
#   'community_board': '10 BRONX',
#   'bbl': '2056250043',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1044042',
#   'y_coordinate_state_plane': '244949',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.83880126216664',
#   'longitude': '-73.7839129078689',
#   'location': {'type': 'Point',
#    'coordinates': [-73.783912907869, 40.838801262167]},
#   ':@computed_region_efsh_h5xi': '11273',
#   ':@computed_region_f5dn_yrer': '43',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '12',
#   ':@computed_region_sbqj_enih': '28'}]

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
len(data)
# Out:
# 1000

# %%
#People call 311 to make the requests - how many call to 311 to make requests
data[99]
# Out:
# {'unique_key': '32670121',
#  'created_date': '2016-02-13T15:05:24.000',
#  'closed_date': '2016-02-14T01:20:43.000',
#  'agency': 'HPD',
#  'agency_name': 'Department of Housing Preservation and Development',
#  'complaint_type': 'HEAT/HOT WATER',
#  'descriptor': 'APARTMENT ONLY',
#  'location_type': 'RESIDENTIAL BUILDING',
#  'incident_zip': '11367',
#  'incident_address': '147-39 73 AVENUE',
#  'street_name': '73 AVENUE',
#  'address_type': 'ADDRESS',
#  'city': 'Flushing',
#  'facility_type': 'N/A',
#  'status': 'Closed',
#  'resolution_description': 'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#  'resolution_action_updated_date': '2016-02-14T01:20:43.000',
#  'community_board': '08 QUEENS',
#  'bbl': '4066810001',
#  'borough': 'QUEENS',
#  'x_coordinate_state_plane': '1034587',
#  'y_coordinate_state_plane': '203605',
#  'open_data_channel_type': 'PHONE',
#  'park_facility_name': 'Unspecified',
#  'park_borough': 'QUEENS',
#  'latitude': '40.72538217324806',
#  'longitude': '-73.8183927522291',
#  'location': {'type': 'Point',
#   'coordinates': [-73.818392752229, 40.725382173248]},
#  ':@computed_region_efsh_h5xi': '14509',
#  ':@computed_region_f5dn_yrer': '25',
#  ':@computed_region_yeji_bk3q': '3',
#  ':@computed_region_92fq_4b7q': '24',
#  ':@computed_region_sbqj_enih': '65'}

# %%
df = pd.DataFrame(data)

print(len(df))
df.head()
# Out:
# 1000
#   :@computed_region_92fq_4b7q :@computed_region_efsh_h5xi  \
# 0                          31                       11271
# 1                          26                       17217
# 2                          23                       12428
# 3                          26                       16866
# 4                          22                       11269
#
#   :@computed_region_f5dn_yrer :@computed_region_sbqj_enih  \
# 0                          58                          26
# 1                           5                          38
# 2                          37                          19
# 3                          61                          40
# 4                          35                          31
#
#   :@computed_region_yeji_bk3q address_type agency  \
# 0                           5      ADDRESS    HPD
# 1                           2      ADDRESS    HPD
# 2                           4      ADDRESS    HPD
# 3                           2      ADDRESS    HPD
# 4                           5      ADDRESS    HPD
#
#                                          agency_name         bbl    borough  \
# 0  Department of Housing Preservation and Develop...  2039437501      BRONX
# 1  Department of Housing Preservation and Develop...  3076300027   BROOKLYN
# 2  Department of Housing Preservation and Develop...  1020700043  MANHATTAN
# 3  Department of Housing Preservation and Develop...  3047370053   BROOKLYN
# 4  Department of Housing Preservation and Develop...  2031250040      BRONX
#
#    ... park_facility_name resolution_action_updated_date  \
# 0  ...        Unspecified        2016-02-13T08:53:35.000
# 1  ...        Unspecified        2016-02-15T13:11:44.000
# 2  ...        Unspecified        2016-02-14T13:35:25.000
# 3  ...        Unspecified        2016-02-17T03:00:54.000
# 4  ...        Unspecified        2016-02-15T20:07:13.000
#
#                               resolution_description  status  \
# 0  The Department of Housing Preservation and Dev...  Closed
# 1  The complaint you filed is a duplicate of a co...  Closed
# 2  The Department of Housing Preservation and Dev...  Closed
# 3  The complaint you filed is a duplicate of a co...  Closed
# 4  The Department of Housing Preservation and Dev...  Closed
#
#         street_name taxi_company_borough taxi_pick_up_location unique_key  \
# 0    UNIONPORT ROAD                  NaN                   NaN   32670008
# 1   NOSTRAND AVENUE                  NaN                   NaN   32670009
# 2  WEST  139 STREET                  NaN                   NaN   32670010
# 3  EAST   52 STREET                  NaN                   NaN   32670011
# 4  BRONX PARK SOUTH                  NaN                   NaN   32670012
#
#   x_coordinate_state_plane y_coordinate_state_plane
# 0                  1023468                   244401
# 1                   999171                   166449
# 2                   997767                   238673
# 3                  1004245                   175133
# 4                  1017180                   247713
#
# [5 rows x 40 columns]
